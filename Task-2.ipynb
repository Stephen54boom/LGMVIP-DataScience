# %% [markdown]
# # **Let's Grow More - Data Science Internship**
#
# **Task-2 : Image to Pencil Sketch with Python**
#
# ---
# **Description**:
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image. Inversion can be used to enhance details. Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image. This can be done by dividing the grayscale image by the inverted blurry image. Since images are just arrays, we can easily do this programmatically using the divide function from the cv2 library in Python.

# %% [markdown]
# **Importing the OpenCV [cv2] library**
#
# Use:
# cv2 [OpenCV] library in python converts any image to an array which we can further use to do some operations.

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# **Step 1: Load the image in OpenCv (cv2)**

# %%
image = cv2.imread('PorscheTaycan.jpg')
cv2_imshow(image)
cv2.waitKey(0)

# %% [markdown]
# **Step 2: Convert Image to RBG format**

# %%
rgb_img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2_imshow(rgb_img)
cv2.waitKey(0)

# %% [markdown]
# **Step 3: Convert RGB Image to Grayscale format**

# %%
gray_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1200x760 at 0x7FD7EABA23D0>
# -1

# %% [markdown]
# **Step 4: Now invert the grayscale image [ Convert Grayscale to Negative format ]**

# %%
inverted_gray_img = 255 - gray_img
cv2_imshow(inverted_gray_img)
cv2.waitKey(0)

# %% [markdown]
# **Step 5: Blur the image using Gaussian Function in OpenCV**

# %%
blur_img = cv2.GaussianBlur(inverted_gray_img, (21, 21), 0)
blur_gray_img = 255 - blur_img
cv2_imshow(blur_gray_img)
cv2.waitKey(0)

# %% [markdown]
# **Step 6: Now let's get Pencil Sketch Image**

# %%
pencil_sketch = cv2.divide(gray_img, blur_gray_img, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)

# %% [markdown]
# **Step 7: Original v/s Pencil Sketch**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketchg)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x760 at 0x7FD7EAB35E50>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-cdc4352eb068> in <module>()
#       1 cv2_imshow(image)
# ----> 2 cv2_imshow(pencil_sketchg)
#       3 cv2.waitKey(0)
#
# NameError: name 'pencil_sketchg' is not defined

# %% [markdown]
# # **Thank You**
